# %%
from simulation import *
# %matplotlib notebook

# %%
file_path = os.path.dirname(sys.argv[0])
full_path = os.path.abspath(file_path)
image_dir = full_path + '/images'

# Configuration 1
user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(99), ak=math.radians(0), axes='rzxy')
user2_rot = T.quaternion_from_euler(ai=math.radians(270), aj=math.radians(99), ak=math.radians(0), axes='rzxy')
user3_rot = T.quaternion_from_euler(ai=math.radians(90), aj=math.radians(99), ak=math.radians(0), axes='rzxy')
# Configuration 2
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(300), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(60), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# Configuration 3
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(70), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(-30), aj=math.radians(70), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(30), aj=math.radians(70), ak=math.radians(0), axes='rzxy')
# Configuration 4
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(-50), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(50), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# Configuration 5
# user1_rot = T.quaternion_from_euler(ai=math.radians(315), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(295), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(270), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# Configuration 6
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(330), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(315), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# Configuration 7
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(-80), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(80), aj=math.radians(75), ak=math.radians(0), axes='rzxy')
# Configuration 8
# user1_rot = T.quaternion_from_euler(ai=math.radians(0), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user2_rot = T.quaternion_from_euler(ai=math.radians(270), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# user3_rot = T.quaternion_from_euler(ai=math.radians(90), aj=math.radians(65), ak=math.radians(0), axes='rzxy')
# Robot rotation
robot_rot = T.quaternion_from_euler(ai=math.radians(180), aj=math.radians(90), ak=math.radians(0), axes='rzxy')

# User Orientation Simulation
# user1_rot = T.quaternion_from_euler(ai=math.radians(180), aj=math.radians(-10), ak=math.radians(0), axes='ryxz')
# user2_rot = T.quaternion_from_euler(ai=math.radians(90), aj=math.radians(-10), ak=math.radians(0), axes='ryxz')
# user3_rot = T.quaternion_from_euler(ai=math.radians(270), aj=math.radians(-10), ak=math.radians(0), axes='ryxz')
# Robot Orientarion Simulation
# robot_rot = T.quaternion_from_euler(ai=math.radians(180), aj=math.radians(0), ak=math.radians(0), axes='ryxz')

# Configuration 1-4, 7-8
user1_translation = (1500.0, 1000.0, 1000.0)
user2_translation = (2500.0, 1500.0, 1000.0)
user3_translation = (500, 1500.0, 1000.0)
# Configuration 5
# user1_translation = (500.0, 1000.0, 1700.0)
# user2_translation = (500.0, 1500.0, 1700.0)
# user3_translation = (500.0, 2000.0, 1700.0)
# Configuration 6
# user1_translation = (1500.0, 1000.0, 1700.0)
# user2_translation = (1000.0, 1200.0, 1700.0)
# user3_translation = (500.0, 1400.0, 1700.0)
# Configuration 7
# Robot Position
robot_translation = (1500.0, 2500.0, 250.0)

# User Position Simulation
# user1_translation = (1500.0, 1000.0, 500.0)
# user2_translation = (3200.0, 1000.0, 1750.0)
# user3_translation = (-250.0, 1000.0, 1750.0)
# Robot Position Simulation
# robot_translation = (1500.0, 300.0, 3000.0)

# Poses
robot_pose = Pose(position=robot_translation, orientation=robot_rot)
user1_pose = Pose(position=user1_translation, orientation=user1_rot)
user2_pose = Pose(position=user2_translation, orientation=user2_rot)
user3_pose = Pose(position=user3_translation, orientation=user3_rot)

# Configuration 1-3
# targets = {'A': np.array([1800.0, 1300.0, 250.0]), 'B': np.array([1500.0, 1300.0, 250.0]),
#            'C': np.array([1200.0, 1300.0, 250.0])}
targets = {'A': np.array([1200.0, 1500.0, 250.0]), 'B': np.array([1500.0, 1500.0, 250.0]),
           'C': np.array([1800.0, 1500.0, 250.0])}
# targets = {'A': np.array([1800.0, 1700.0, 250.0]), 'B': np.array([1500.0, 1700.0, 250.0]),
#            'C': np.array([1200.0, 1700.0, 250.0])}
# Configuration 4
# targets = {'A': np.array([1250.0, 1600.0, 250.0]), 'B': np.array([1750.0, 1600.0, 250.0]),
#            'C': np.array([1500.0, 1300.0, 250.0])}
# Configuration 5
# targets = {'A': np.array([1200.0, 1500.0, 250.0]), 'B': np.array([1500.0, 1500.0, 250.0]),
#            'C': np.array([1800.0, 1500.0, 250.0])}
# Configuration 6
# targets = {'A': np.array([1250.0, 1700.0, 250.0]), 'B': np.array([1500.0, 1500.0, 250.0]),
#            'C': np.array([1800.0, 1300.0, 250.0])}
# Configuration 7
# targets = {'A': np.array([1250.0, 1600.0, 250.0]), 'B': np.array([1500.0, 1800.0, 250.0]),
#            'C': np.array([1750.0, 1600.0, 250.0])}
# Configuration 8
# targets = {'A': np.array([1500.0, 1200.0, 250.0]), 'B': np.array([1500.0, 1800.0, 250.0]),
#            'C': np.array([1500.0, 1500.0, 250.0])}
movement_start = np.array([1500., 2000., 250.])

# Target Position Simulation
# targets = {'A': np.array([1800.0, 250.0, 1700.0]), 'B': np.array([1500.0, 250.0, 1700.0]),
#            'C': np.array([1200.0, 250.0, 1700.0])}
# targets = {'A': np.array([1650.0, 250.0, 1700.0]), 'B': np.array([1500.0, 250.0, 1500.0]),
#           'C': np.array([1300.0, 250.0, 1700.0])}
# targets = {'A': np.array([1650.0, 250.0, 1700.0]), 'B': np.array([1500.0, 250.0, 1900.0]),
#            'C': np.array([1300.0, 250.0, 1700.0])}
# targets = {'A': np.array([1650.0, 250.0, 1700.0]), 'B': np.array([1500.0, 250.0, 1700.0]),
#            'C': np.array([1350.0, 250.0, 1700.0])}
# targets = {'A': np.array([1600.0, 250.0, 1800.0]), 'B': np.array([1600.0, 250.0, 1600.0]),
#            'C': np.array([1400.0, 250.0, 1700.0])}
# targets = {'A': np.array([1500.0, 250.0, 2000.0]), 'B': np.array([1500.0, 250.0, 1400.0]),
#            'C': np.array([1500.0, 250.0, 1700.0])}
# targets = {'A': np.array([1400, 250.0, 1800.0]), 'B': np.array([1400.0, 250.0, 1600.0]),
#            'C': np.array([1600.0, 250.0, 1700.0])}
# movement_start = np.array([1500., 250., 2400.])

# Parameterization
optimization_criteria = 'avg'
# optimization_criteria = 'minmax'
vertical_fov = 55
horizontal_fov = 120
n_iterations = 500
learn_rate = (1.0 / 0.005)
n_users = 3
n_targets = len(targets)
optim_target = 'A'
user_poses = [user1_pose, user2_pose, user3_pose]
# user_poses = [user2_pose]
u_ids = ['user1', 'user2', 'user3']
# u_ids = ['user2']
filename = "../data/3_users_multiple_trajs.csv"
# filename = "../data/1_user_conf_7_u2_c.csv"
targets_pos = list(targets.values())

# Variables and definitions for performance evaluation
user_poses_defined = [user1_pose, user2_pose, user3_pose]
user_defined_ids = ['user1', 'user2', 'user3']

# Trajectory Creation
n_points = 20
traj_x = np.linspace(movement_start[0], targets[optim_target][0], num=n_points)[:, None]
traj_y = np.linspace(movement_start[1], targets[optim_target][1], num=n_points)[:, None]
traj_z = np.linspace(movement_start[2], targets[optim_target][2], num=n_points)[:, None]
# offset_modulator = 300 * np.sin(np.linspace(0, np.pi, num=n_points))[:, None]
# Trajectory Creation Simulation
# traj_x = np.linspace(robot_translation[0], targets[optim_target][0], num=n_points)[:, None]
# traj_y = np.linspace(targets[optim_target][1], targets[optim_target][1], num=n_points)[:, None]
# traj_z = np.linspace(robot_translation[2], targets[optim_target][2], num=n_points)[:, None]

base_traj = np.hstack((traj_x, traj_y, traj_z))
# h_mod_traj = np.hstack((traj_x, traj_y, traj_z + offset_modulator))
# r_mod_traj = np.hstack((traj_x - offset_modulator, traj_y, traj_z))
# l_mod_traj = np.hstack((traj_x + offset_modulator, traj_y, traj_z))
# hr_mod_traj = np.hstack((traj_x - offset_modulator, traj_y, traj_z + offset_modulator))
# hl_mod_traj = np.hstack((traj_x + offset_modulator, traj_y, traj_z + offset_modulator))
# r_spring_mod_traj = np.hstack((traj_x - offset_modulator, traj_y - offset_modulator, traj_z))
# l_spring_mod_traj = np.hstack((traj_x + offset_modulator, traj_y - offset_modulator, traj_z))
trajectories_sequence = [base_traj]
# trajectories_sequence = [base_traj, h_mod_traj, r_mod_traj, l_mod_traj, hr_mod_traj, hl_mod_traj,
#                         r_spring_mod_traj, l_spring_mod_traj]
# sim_traj = np.array([[1500., 160., 2400.],
#                                     [2229.021972179, 1094.811820603, 2461.051873488],
#                                     [2571.8057386, 1506.11742086, 2458.223506832],
#                                     [2872.351479368, 1851.053369991, 2447.210246514],
#                                     [3120.154370452, 2128.359522994, 2429.038810527],
#                                     [3310.678325223, 2339.968867038, 2404.593332164],
#                                     [3443.547464953, 2489.092021494, 2374.639322125],
#                                     [3521.019854748, 2579.365000782, 2339.848584302],
#                                     [3546.978897975, 2614.510178001, 2300.819647367],
#                                     [3526.311904584, 2598.229211488, 2258.093125113],
#                                     [3464.525347153, 2534.198077236, 2212.1	62931701],
#                                     [3367.491152402, 2426.107619416, 2163.484458679],
#                                     [3241.257556712, 2277.726841934, 2112.48062589],
#                                     [3091.882701003, 2092.982322426, 2059.546485411],
#                                     [2925.262519803, 1876.056412666, 2005.052872246],
#                                     [2746.92998649, 1631.515154348, 1949.34945329],
#                                     [2561.801757288, 1364.489093098, 1892.767367143],
#                                     [2373.838764493, 1080.953094552, 1835.621242909],
#                                     [2185.560274537, 788.181309142, 1778.20861065],
#                                     [1800., 160., 1700.]])

# %%
# user1 = UserPerspectiveLegibility(using_ros=False, orientation_type='euler', user_id='user1',
#                                   user_pose=user1_pose, robot_pose=robot_pose)
# user2 = UserPerspectiveLegibility(using_ros=False, orientation_type='euler', user_id='user2',
#                                   user_pose=user2_pose, robot_pose=robot_pose)
# user3 = UserPerspectiveLegibility(using_ros=False, orientation_type='euler', user_id='user3',
#                                   user_pose=user3_pose, robot_pose=robot_pose)

# user1_traj = user1.transformTrajectory(base_traj, viewport=False)
# user2_traj = user2.transformTrajectory(base_traj, viewport=False)
# user3_traj = user3.transformTrajectory(base_traj, viewport=False)
# user1_traj = user1.transformTrajectory(sim_traj, viewport=False)
# user2_traj = user2.transformTrajectory(sim_traj, viewport=False)
# user3_traj = user3.transformTrajectory(sim_traj, viewport=False)

# user1_transformed_u1 = np.array([0, 0, 0])
# user1_transformed_u2 = user2.transformTrajectory(np.array([user1_translation]), viewport=False)[0]
# user1_transformed_u3 = user3.transformTrajectory(np.array([user1_translation]), viewport=False)[0]
# user2_transformed_u1 = user1.transformTrajectory(np.array([user2_translation]), viewport=False)[0]
# user2_transformed_u2 = np.array([0, 0, 0])
# user2_transformed_u3 = user3.transformTrajectory(np.array([user2_translation]), viewport=False)[0]
# user3_transformed_u1 = user1.transformTrajectory(np.array([user3_translation]), viewport=False)[0]
# user3_transformed_u2 = user2.transformTrajectory(np.array([user3_translation]), viewport=False)[0]
# user3_transformed_u3 = np.array([0, 0, 0])
# robot_transformed_u1 = user1.transformTrajectory(np.array([robot_translation]), viewport=False)[0]
# robot_transformed_u2 = user2.transformTrajectory(np.array([robot_translation]), viewport=False)[0]
# robot_transformed_u3 = user3.transformTrajectory(np.array([robot_translation]), viewport=False)[0]
# targets_u1 = {'A': user1.transformTrajectory(np.array([targets['A']]), viewport=False)[0],
# 			'B': user1.transformTrajectory(np.array([targets['B']]), viewport=False)[0],
# 			'C': user1.transformTrajectory(np.array([targets['C']]), viewport=False)[0]}
# targets_u2 = {'A': user2.transformTrajectory(np.array([targets['A']]), viewport=False)[0],
# 			 'B': user2.transformTrajectory(np.array([targets['B']]), viewport=False)[0],
# 			 'C': user2.transformTrajectory(np.array([targets['C']]), viewport=False)[0]}
# targets_u3 = {'A': user3.transformTrajectory(np.array([targets['A']]), viewport=False)[0],
# 			 'B': user3.transformTrajectory(np.array([targets['B']]), viewport=False)[0],
# 			 'C': user3.transformTrajectory(np.array([targets['C']]), viewport=False)[0]}

# print('Original Trajectory')
# print(base_traj)
# print('User 1 transformed trajectory')
# print(user1_traj)
# print('User 2 transformed trajectory')
# print(user2_traj)
# print('User 3 transformed trajectory')
# print(user3_traj)

# fig = plt.figure('Original Trajectory')
# ax = fig.add_subplot(111, projection=Axes3D.name)
# ax.plot(base_traj[:, 0], base_traj[:, 1], base_traj[:, 2], 'black', label='Trajectory', marker='.', linestyle="None")
# ax.plot(np.array([user1_translation[0]]), np.array([user1_translation[1]]), np.array([user1_translation[2]]),
#         color='red', marker='2', markersize=15, label='User1')
# ax.plot(np.array([user2_translation[0]]), np.array([user2_translation[1]]), np.array([user2_translation[2]]),
#         color='green', marker='2', markersize=15, label='User2')
# ax.plot(np.array([user3_translation[0]]), np.array([user3_translation[1]]), np.array([user3_translation[2]]),
#         color='brown', marker='2', markersize=15, label='User3')
# ax.plot(np.array([robot_translation[0]]), np.array([robot_translation[1]]), np.array([robot_translation[2]]),
#         color='blue', marker='2', markersize=15, label='Robot')
# ax.plot(np.array([targets['A'][0]]), np.array([targets['A'][1]]), np.array([targets['A'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets['B'][0]]), np.array([targets['B'][1]]), np.array([targets['B'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets['C'][0]]), np.array([targets['C'][1]]), np.array([targets['C'][2]]),
#         color='darkorange', marker='D', markersize=10)
# plt.legend(loc='best')
# ax.view_init(azim=180, elev=-10)
# fig.show()

# fig = plt.figure('Trajectories Visual')
# ax = fig.add_subplot(111, projection=Axes3D.name)
# ax.plot(base_traj[:, 0], base_traj[:, 1], base_traj[:, 2], 'black', label='Base', marker='.',
# 		linestyle="None")
# ax.plot(h_mod_traj[:, 0], h_mod_traj[:, 1], h_mod_traj[:, 2], 'blue', label='Height', marker='.',
# 		linestyle="None")
# ax.plot(r_mod_traj[:, 0], r_mod_traj[:, 1], r_mod_traj[:, 2], 'green', label='Right', marker='.',
# 		linestyle="None")
# ax.plot(l_mod_traj[:, 0], l_mod_traj[:, 1], l_mod_traj[:, 2], 'cyan', label='Left', marker='.',
# 		linestyle="None")
# ax.plot(hr_mod_traj[:, 0], hr_mod_traj[:, 1], hr_mod_traj[:, 2], 'red', label='Right Height', marker='.',
# 		linestyle="None")
# ax.plot(hl_mod_traj[:, 0], hl_mod_traj[:, 1], hl_mod_traj[:, 2], 'orange', label='Left Height', marker='.',
# 		linestyle="None")
# ax.plot(r_spring_mod_traj[:, 0], r_spring_mod_traj[:, 1], r_spring_mod_traj[:, 2], 'brown', label='Right Spring',
# 		marker='.', linestyle="None")
# ax.plot(l_spring_mod_traj[:, 0], l_spring_mod_traj[:, 1], l_spring_mod_traj[:, 2], 'pink', label='Left Spring',
# 		marker='.', linestyle="None")
# ax.plot(np.array([user1_translation[0]]), np.array([user1_translation[1]]), np.array([user1_translation[2]]),
#         color='red', marker='2', markersize=15, label='User1')
# ax.plot(np.array([user2_translation[0]]), np.array([user2_translation[1]]), np.array([user2_translation[2]]),
#         color='green', marker='2', markersize=15, label='User2')
# ax.plot(np.array([user3_translation[0]]), np.array([user3_translation[1]]), np.array([user3_translation[2]]),
#         color='brown', marker='2', markersize=15, label='User3')
# ax.plot(np.array([robot_translation[0]]), np.array([robot_translation[1]]), np.array([robot_translation[2]]),
#         color='blue', marker='2', markersize=15, label='Robot')
# ax.plot(np.array([targets['A'][0]]), np.array([targets['A'][1]]), np.array([targets['A'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets['B'][0]]), np.array([targets['B'][1]]), np.array([targets['B'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets['C'][0]]), np.array([targets['C'][1]]), np.array([targets['C'][2]]),
#         color='darkorange', marker='D', markersize=10)
# plt.legend(loc='best')
# fig.show()

# fig = plt.figure('Trajectories Visual User')
# ax = fig.add_subplot(111, projection=Axes3D.name)
# ax.plot(user2_traj[:, 0], user2_traj[:, 1], user2_traj[:, 2], 'black', label='Base')
# ax.plot(np.array([user1_transformed_u2[0]]), np.array([user1_transformed_u2[1]]), np.array([user1_transformed_u2[2]]),
#         color='red', marker='$User_1$', markersize=15, label='User1')
# ax.plot(np.array([user2_transformed_u2[0]]), np.array([user2_transformed_u2[1]]), np.array([user2_transformed_u2[2]]),
#         color='green', marker='2', markersize=15, label='User2')
# ax.plot(np.array([user3_transformed_u2[0]]), np.array([user3_transformed_u2[1]]), np.array([user3_transformed_u2[2]]),
#         color='brown', marker='$User_3$', markersize=15, label='User3')
# ax.plot(np.array([robot_transformed_u2[0]]), np.array([robot_transformed_u2[1]]), np.array([robot_transformed_u2[2]]),
#         color='blue', marker='o', markersize=7, label='Robot')
# ax.plot(np.array([targets_u2['A'][0]]), np.array([targets_u2['A'][1]]), np.array([targets_u2['A'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets_u2['B'][0]]), np.array([targets_u2['B'][1]]), np.array([targets_u2['B'][2]]),
#         color='darkorange', marker='D', markersize=10)
# ax.plot(np.array([targets_u2['C'][0]]), np.array([targets_u2['C'][1]]), np.array([targets_u2['C'][2]]),
#         color='darkorange', marker='D', markersize=10)
# plt.legend(loc='best')
# ax.view_init(azim=-90, elev=120)
# fig.show()

# x = input()

# %%
# Run simulation
n_trajectories = 1
robot_model = IRB4600()
use_joints = True
for i in range(n_trajectories):
    print('Initial Trajectory')
    if use_joints:
        traj = prepare_trajectory(trajectories_sequence[i], robot_pose, robot_model)
    else:
        traj = trajectories_sequence[i]
    run_simulation(filename, learn_rate, optimization_criteria, n_iterations, optim_target, traj, n_targets, targets,
                   targets_pos, n_users, user_poses, u_ids, robot_pose, horizontal_fov, vertical_fov, user_defined_ids,
                   user_poses_defined, use_joints=use_joints, robot_model=robot_model, store_mode='optim', plotting=True)

print('------------------------------------------')
print('-------- OPTIMIZATION PROGRAM ENDED ------')
print('------------------------------------------')
# Out:
# Initial Trajectory
# Iteration: 1
# User: user1	Legibility: 0.46078
# User: user2	Legibility: 0.46654
# User: user3	Legibility: 0.48470
# Legibility improvement: 0.470672727
# Average Legibility: 0.47067
# Iteration: 2
# Legibility improvement: 0.003861673
# Iteration: 3
# Legibility improvement: 0.003840730
# Iteration: 4
# Legibility improvement: 0.003818411
# Iteration: 5
# Legibility improvement: 0.003794883
# Iteration: 6
# Legibility improvement: 0.003770302
# Iteration: 7
# Legibility improvement: 0.003744816
# Iteration: 8
# Legibility improvement: 0.003718563
# Iteration: 9
# Legibility improvement: 0.003691670
# Iteration: 10
# Legibility improvement: 0.003664255
# Iteration: 11
# Legibility improvement: 0.003636426
# Iteration: 12
# Legibility improvement: 0.003608280
# Iteration: 13
# Legibility improvement: 0.003579905
# Iteration: 14
# Legibility improvement: 0.003551380
# Iteration: 15
# Legibility improvement: 0.003522777
# Iteration: 16
# Legibility improvement: 0.003494156
# Iteration: 17
# Legibility improvement: 0.003465572
# Iteration: 18
# Legibility improvement: 0.003437072
# Iteration: 19
# Legibility improvement: 0.003408695
# Iteration: 20
# Legibility improvement: 0.003380475
# Iteration: 21
# Legibility improvement: 0.003352439
# Iteration: 22
# Legibility improvement: 0.003324609
# Iteration: 23
# Legibility improvement: 0.003297003
# Iteration: 24
# Legibility improvement: 0.003269634
# Iteration: 25
# Legibility improvement: 0.003242509
# Iteration: 26
# Legibility improvement: 0.003215634
# Iteration: 27
# Legibility improvement: 0.003189012
# Iteration: 28
# Legibility improvement: 0.003162641
# Iteration: 29
# Legibility improvement: 0.003136519
# Iteration: 30
# Legibility improvement: 0.003110639
# Iteration: 31
# Legibility improvement: 0.003084996
# Iteration: 32
# Legibility improvement: 0.003059580
# Iteration: 33
# Legibility improvement: 0.003034383
# Iteration: 34
# Legibility improvement: 0.003009393
# Iteration: 35
# Legibility improvement: 0.002984600
# Iteration: 36
# Legibility improvement: 0.002959992
# Iteration: 37
# Legibility improvement: 0.002935557
# Iteration: 38
# Legibility improvement: 0.002911282
# Iteration: 39
# Legibility improvement: 0.002887157
# Iteration: 40
# Legibility improvement: 0.002863168
# Iteration: 41
# Legibility improvement: 0.002839305
# Iteration: 42
# Legibility improvement: 0.002815555
# Iteration: 43
# Legibility improvement: 0.002791908
# Iteration: 44
# Legibility improvement: 0.002768354
# Iteration: 45
# Legibility improvement: 0.002744883
# Iteration: 46
# Legibility improvement: 0.002721485
# Iteration: 47
# Legibility improvement: 0.002698153
# Iteration: 48
# Legibility improvement: 0.002674878
# Iteration: 49
# Legibility improvement: 0.002651654
# Iteration: 50
# Legibility improvement: 0.002628474
# Iteration: 51
# Legibility improvement: 0.002605332
# Iteration: 52
# Legibility improvement: 0.002582225
# Iteration: 53
# Legibility improvement: 0.002559147
# Iteration: 54
# Legibility improvement: 0.002536096
# Iteration: 55
# Legibility improvement: 0.002513069
# Iteration: 56
# Legibility improvement: 0.002490064
# Iteration: 57
# Legibility improvement: 0.002467080
# Iteration: 58
# Legibility improvement: 0.002444116
# Iteration: 59
# Legibility improvement: 0.002421172
# Iteration: 60
# Legibility improvement: 0.002398250
# Iteration: 61
# Legibility improvement: 0.002375350
# Iteration: 62
# Legibility improvement: 0.002352474
# Iteration: 63
# Legibility improvement: 0.002329624
# Iteration: 64
# Legibility improvement: 0.002306804
# Iteration: 65
# Legibility improvement: 0.002284015
# Iteration: 66
# Legibility improvement: 0.002261261
# Iteration: 67
# Legibility improvement: 0.002238547
# Iteration: 68
# Legibility improvement: 0.002215877
# Iteration: 69
# Legibility improvement: 0.002193254
# Iteration: 70
# Legibility improvement: 0.002170683
# Iteration: 71
# Legibility improvement: 0.002148169
# Iteration: 72
# Legibility improvement: 0.002125718
# Iteration: 73
# Legibility improvement: 0.002103333
# Iteration: 74
# Legibility improvement: 0.002081021
# Iteration: 75
# Legibility improvement: 0.002058786
# Iteration: 76
# Legibility improvement: 0.002036634
# Iteration: 77
# Legibility improvement: 0.002014569
# Iteration: 78
# Legibility improvement: 0.001992599
# Iteration: 79
# Legibility improvement: 0.001970726
# Iteration: 80
# Legibility improvement: 0.001948958
# Iteration: 81
# Legibility improvement: 0.001927298
# Iteration: 82
# Legibility improvement: 0.001905752
# Iteration: 83
# Legibility improvement: 0.001884325
# Iteration: 84
# Legibility improvement: 0.001863021
# Iteration: 85
# Legibility improvement: 0.001841846
# Iteration: 86
# Legibility improvement: 0.001820803
# Iteration: 87
# Legibility improvement: 0.001799897
# Iteration: 88
# Legibility improvement: 0.001779132
# Iteration: 89
# Legibility improvement: 0.001758513
# Iteration: 90
# Legibility improvement: 0.001738042
# Iteration: 91
# Legibility improvement: 0.001717723
# Iteration: 92
# Legibility improvement: 0.001697561
# Iteration: 93
# Legibility improvement: 0.001677558
# Iteration: 94
# Legibility improvement: 0.001657717
# Iteration: 95
# Legibility improvement: 0.001638041
# Iteration: 96
# Legibility improvement: 0.001618533
# Iteration: 97
# Legibility improvement: 0.001599194
# Iteration: 98
# Legibility improvement: 0.001580029
# Iteration: 99
# Legibility improvement: 0.001561037
# Iteration: 100
# User: user1	Legibility: 0.74058
# User: user2	Legibility: 0.66465
# User: user3	Legibility: 0.79035
# Legibility improvement: 0.001542222
# Average Legibility: 0.73186
# Iteration: 101
# Legibility improvement: 0.001523586
# Iteration: 102
# Legibility improvement: 0.001505128
# Iteration: 103
# Legibility improvement: 0.001486852
# Iteration: 104
# Legibility improvement: 0.001468758
# Iteration: 105
# Legibility improvement: 0.001450847
# Iteration: 106
# Legibility improvement: 0.001433120
# Iteration: 107
# Legibility improvement: 0.001415578
# Iteration: 108
# Legibility improvement: 0.001398221
# Iteration: 109
# Legibility improvement: 0.001381050
# Iteration: 110
# Legibility improvement: 0.001364065
# Iteration: 111
# Legibility improvement: 0.001347267
# Iteration: 112
# Legibility improvement: 0.001330654
# Iteration: 113
# Legibility improvement: 0.001314229
# Iteration: 114
# Legibility improvement: 0.001297989
# Iteration: 115
# Legibility improvement: 0.001281935
# Iteration: 116
# Legibility improvement: 0.001266067
# Iteration: 117
# Legibility improvement: 0.001250384
# Iteration: 118
# Legibility improvement: 0.001234885
# Iteration: 119
# Legibility improvement: 0.001219570
# Iteration: 120
# Legibility improvement: 0.001204439
# Iteration: 121
# Legibility improvement: 0.001189490
# Iteration: 122
# Legibility improvement: 0.001174723
# Iteration: 123
# Legibility improvement: 0.001160136
# Iteration: 124
# Legibility improvement: 0.001145729
# Iteration: 125
# Legibility improvement: 0.001131501
# Iteration: 126
# Legibility improvement: 0.001117450
# Iteration: 127
# Legibility improvement: 0.001103576
# Iteration: 128
# Legibility improvement: 0.001089877
# Iteration: 129
# Legibility improvement: 0.001076353
# Iteration: 130
# Legibility improvement: 0.001063001
# Iteration: 131
# Legibility improvement: 0.001049821
# Iteration: 132
# Legibility improvement: 0.001036811
# Iteration: 133
# Legibility improvement: 0.001023970
# Iteration: 134
# Legibility improvement: 0.001011297
# Iteration: 135
# Legibility improvement: 0.000998790
# Iteration: 136
# Legibility improvement: 0.000986447
# Iteration: 137
# Legibility improvement: 0.000974268
# Iteration: 138
# Legibility improvement: 0.000962250
# Iteration: 139
# Legibility improvement: 0.000950393
# Iteration: 140
# Legibility improvement: 0.000938695
# Iteration: 141
# Legibility improvement: 0.000927153
# Iteration: 142
# Legibility improvement: 0.000915767
# Iteration: 143
# Legibility improvement: 0.000904536
# Iteration: 144
# Legibility improvement: 0.000893457
# Iteration: 145
# Legibility improvement: 0.000882528
# Iteration: 146
# Legibility improvement: 0.000871750
# Iteration: 147
# Legibility improvement: 0.000861118
# Iteration: 148
# Legibility improvement: 0.000850633
# Iteration: 149
# Legibility improvement: 0.000840293
# Iteration: 150
# Legibility improvement: 0.000830095
# Iteration: 151
# Legibility improvement: 0.000820038
# Iteration: 152
# Legibility improvement: 0.000810122
# Iteration: 153
# Legibility improvement: 0.000800343
# Iteration: 154
# Legibility improvement: 0.000790700
# Iteration: 155
# Legibility improvement: 0.000781193
# Iteration: 156
# Legibility improvement: 0.000771818
# Iteration: 157
# Legibility improvement: 0.000762575
# Iteration: 158
# Legibility improvement: 0.000753461
# Iteration: 159
# Legibility improvement: 0.000744476
# Iteration: 160
# Legibility improvement: 0.000735618
# Iteration: 161
# Legibility improvement: 0.000726885
# Iteration: 162
# Legibility improvement: 0.000718275
# Iteration: 163
# Legibility improvement: 0.000709786
# Iteration: 164
# Legibility improvement: 0.000701418
# Iteration: 165
# Legibility improvement: 0.000693169
# Iteration: 166
# Legibility improvement: 0.000685037
# Iteration: 167
# Legibility improvement: 0.000677020
# Iteration: 168
# Legibility improvement: 0.000669117
# Iteration: 169
# Legibility improvement: 0.000661327
# Iteration: 170
# Legibility improvement: 0.000653647
# Iteration: 171
# Legibility improvement: 0.000646077
# Iteration: 172
# Legibility improvement: 0.000638614
# Iteration: 173
# Legibility improvement: 0.000631258
# Iteration: 174
# Legibility improvement: 0.000624007
# Iteration: 175
# Legibility improvement: 0.000616859
# Iteration: 176
# Legibility improvement: 0.000609813
# Iteration: 177
# Legibility improvement: 0.000602867
# Iteration: 178
# Legibility improvement: 0.000596020
# Iteration: 179
# Legibility improvement: 0.000589271
# Iteration: 180
# Legibility improvement: 0.000582618
# Iteration: 181
# Legibility improvement: 0.000576059
# Iteration: 182
# Legibility improvement: 0.000569594
# Iteration: 183
# Legibility improvement: 0.000563221
# Iteration: 184
# Legibility improvement: 0.000556938
# Iteration: 185
# Legibility improvement: 0.000550745
# Iteration: 186
# Legibility improvement: 0.000544639
# Iteration: 187
# Legibility improvement: 0.000538620
# Iteration: 188
# Legibility improvement: 0.000532686
# Iteration: 189
# Legibility improvement: 0.000526836
# Iteration: 190
# Legibility improvement: 0.000521069
# Iteration: 191
# Legibility improvement: 0.000515383
# Iteration: 192
# Legibility improvement: 0.000509777
# Iteration: 193
# Legibility improvement: 0.000504250
# Iteration: 194
# Legibility improvement: 0.000498801
# Iteration: 195
# Legibility improvement: 0.000493428
# Iteration: 196
# Legibility improvement: 0.000488130
# Iteration: 197
# Legibility improvement: 0.000482907
# Iteration: 198
# Legibility improvement: 0.000477756
# Iteration: 199
# Legibility improvement: 0.000472677
# Iteration: 200
# User: user1	Legibility: 0.86226
# User: user2	Legibility: 0.73228
# User: user3	Legibility: 0.86603
# Legibility improvement: 0.000467669
# Average Legibility: 0.82019
# Iteration: 201
# Legibility improvement: 0.000462730
# Iteration: 202
# Legibility improvement: 0.000457860
# Iteration: 203
# Legibility improvement: 0.000453057
# Iteration: 204
# Legibility improvement: 0.000448320
# Iteration: 205
# Legibility improvement: 0.000443649
# Iteration: 206
# Legibility improvement: 0.000439042
# Iteration: 207
# Legibility improvement: 0.000434497
# Iteration: 208
# Legibility improvement: 0.000430015
# Iteration: 209
# Legibility improvement: 0.000425594
# Iteration: 210
# Legibility improvement: 0.000421233
# Iteration: 211
# Legibility improvement: 0.000416931
# Iteration: 212
# Legibility improvement: 0.000412688
# Iteration: 213
# Legibility improvement: 0.000408501
# Iteration: 214
# Legibility improvement: 0.000404371
# Iteration: 215
# Legibility improvement: 0.000400296
# Iteration: 216
# Legibility improvement: 0.000396276
# Iteration: 217
# Legibility improvement: 0.000392309
# Iteration: 218
# Legibility improvement: 0.000388395
# Iteration: 219
# Legibility improvement: 0.000384533
# Iteration: 220
# Legibility improvement: 0.000380722
# Iteration: 221
# Legibility improvement: 0.000376961
# Iteration: 222
# Legibility improvement: 0.000373250
# Iteration: 223
# Legibility improvement: 0.000369587
# Iteration: 224
# Legibility improvement: 0.000365972
# Iteration: 225
# Legibility improvement: 0.000362403
# Iteration: 226
# Legibility improvement: 0.000358881
# Iteration: 227
# Legibility improvement: 0.000355405
# Iteration: 228
# Legibility improvement: 0.000351973
# Iteration: 229
# Legibility improvement: 0.000348585
# Iteration: 230
# Legibility improvement: 0.000345240
# Iteration: 231
# Legibility improvement: 0.000341938
# Iteration: 232
# Legibility improvement: 0.000338678
# Iteration: 233
# Legibility improvement: 0.000335458
# Iteration: 234
# Legibility improvement: 0.000332280
# Iteration: 235
# Legibility improvement: 0.000329141
# Iteration: 236
# Legibility improvement: 0.000326041
# Iteration: 237
# Legibility improvement: 0.000322980
# Iteration: 238
# Legibility improvement: 0.000319956
# Iteration: 239
# Legibility improvement: 0.000316970
# Iteration: 240
# Legibility improvement: 0.000314021
# Iteration: 241
# Legibility improvement: 0.000311107
# Iteration: 242
# Legibility improvement: 0.000308229
# Iteration: 243
# Legibility improvement: 0.000305386
# Iteration: 244
# Legibility improvement: 0.000302578
# Iteration: 245
# Legibility improvement: 0.000299802
# Iteration: 246
# Legibility improvement: 0.000297060
# Iteration: 247
# Legibility improvement: 0.000294351
# Iteration: 248
# Legibility improvement: 0.000291674
# Iteration: 249
# Legibility improvement: 0.000289028
# Iteration: 250
# Legibility improvement: 0.000286414
# Iteration: 251
# Legibility improvement: 0.000283829
# Iteration: 252
# Legibility improvement: 0.000281275
# Iteration: 253
# Legibility improvement: 0.000278751
# Iteration: 254
# Legibility improvement: 0.000276255
# Iteration: 255
# Legibility improvement: 0.000273789
# Iteration: 256
# Legibility improvement: 0.000271350
# Iteration: 257
# Legibility improvement: 0.000268939
# Iteration: 258
# Legibility improvement: 0.000266555
# Iteration: 259
# Legibility improvement: 0.000264198
# Iteration: 260
# Legibility improvement: 0.000261867
# Iteration: 261
# Legibility improvement: 0.000259563
# Iteration: 262
# Legibility improvement: 0.000257283
# Iteration: 263
# Legibility improvement: 0.000255029
# Iteration: 264
# Legibility improvement: 0.000252800
# Iteration: 265
# Legibility improvement: 0.000250595
# Iteration: 266
# Legibility improvement: 0.000248414
# Iteration: 267
# Legibility improvement: 0.000246256
# Iteration: 268
# Legibility improvement: 0.000244122
# Iteration: 269
# Legibility improvement: 0.000242011
# Iteration: 270
# Legibility improvement: 0.000239922
# Iteration: 271
# Legibility improvement: 0.000237856
# Iteration: 272
# Legibility improvement: 0.000235811
# Iteration: 273
# Legibility improvement: 0.000233788
# Iteration: 274
# Legibility improvement: 0.000231786
# Iteration: 275
# Legibility improvement: 0.000229805
# Iteration: 276
# Legibility improvement: 0.000227844
# Iteration: 277
# Legibility improvement: 0.000225904
# Iteration: 278
# Legibility improvement: 0.000223985
# Iteration: 279
# Legibility improvement: 0.000222084
# Iteration: 280
# Legibility improvement: 0.000220204
# Iteration: 281
# Legibility improvement: 0.000218343
# Iteration: 282
# Legibility improvement: 0.000216500
# Iteration: 283
# Legibility improvement: 0.000214677
# Iteration: 284
# Legibility improvement: 0.000212872
# Iteration: 285
# Legibility improvement: 0.000211085
# Iteration: 286
# Legibility improvement: 0.000209316
# Iteration: 287
# Legibility improvement: 0.000207566
# Iteration: 288
# Legibility improvement: 0.000205832
# Iteration: 289
# Legibility improvement: 0.000204117
# Iteration: 290
# Legibility improvement: 0.000202418
# Iteration: 291
# Legibility improvement: 0.000200737
# Iteration: 292
# Legibility improvement: 0.000199072
# Iteration: 293
# Legibility improvement: 0.000197424
# Iteration: 294
# Legibility improvement: 0.000195793
# Iteration: 295
# Legibility improvement: 0.000194177
# Iteration: 296
# Legibility improvement: 0.000192578
# Iteration: 297
# Legibility improvement: 0.000190995
# Iteration: 298
# Legibility improvement: 0.000189427
# Iteration: 299
# Legibility improvement: 0.000187876
# Iteration: 300
# User: user1	Legibility: 0.90206
# User: user2	Legibility: 0.75011
# User: user3	Legibility: 0.89787
# Legibility improvement: 0.000186339
# Average Legibility: 0.85001
# Iteration: 301
# Legibility improvement: 0.000184818
# Iteration: 302
# Legibility improvement: 0.000183312
# Iteration: 303
# Legibility improvement: 0.000181821
# Iteration: 304
# Legibility improvement: 0.000180344
# Iteration: 305
# Legibility improvement: 0.000178883
# Iteration: 306
# Legibility improvement: 0.000177436
# Iteration: 307
# Legibility improvement: 0.000176003
# Iteration: 308
# Legibility improvement: 0.000174584
# Iteration: 309
# Legibility improvement: 0.000173180
# Iteration: 310
# Legibility improvement: 0.000171789
# Iteration: 311
# Legibility improvement: 0.000170413
# Iteration: 312
# Legibility improvement: 0.000169050
# Iteration: 313
# Legibility improvement: 0.000167700
# Iteration: 314
# Legibility improvement: 0.000166364
# Iteration: 315
# Legibility improvement: 0.000165041
# Iteration: 316
# Legibility improvement: 0.000163731
# Iteration: 317
# Legibility improvement: 0.000162435
# Iteration: 318
# Legibility improvement: 0.000161150
# Iteration: 319
# Legibility improvement: 0.000159879
# Iteration: 320
# Legibility improvement: 0.000158620
# Iteration: 321
# Legibility improvement: 0.000157374
# Iteration: 322
# Legibility improvement: 0.000156140
# Iteration: 323
# Legibility improvement: 0.000154918
# Iteration: 324
# Legibility improvement: 0.000153708
# Iteration: 325
# Legibility improvement: 0.000152510
# Iteration: 326
# Legibility improvement: 0.000151323
# Iteration: 327
# Legibility improvement: 0.000150149
# Iteration: 328
# Legibility improvement: 0.000148985
# Iteration: 329
# Legibility improvement: 0.000147833
# Iteration: 330
# Legibility improvement: 0.000146692
# Iteration: 331
# Legibility improvement: 0.000145562
# Iteration: 332
# Legibility improvement: 0.000144443
# Iteration: 333
# Improved trajectory unfeasable. Stopping optimization process
# /mnt/c/Users/Miguel/Desktop/My_Documents/Instituto.Superior.Tecnico/PhD/movement_communication/multiuser_legible_movement/src/user_perspective_legibility.py:708: RuntimeWarning: invalid value encountered in true_divide
#   partial_trajectory_legibility = (prob_target_traj_targets[self._target] *
# <img src="data:image/png;base64,..." width="640">
# ----------------------------------------
# |--------------------------------------|
# |                                      |
# |         Optimization Results         |
# |                                      |
# |--------------------------------------|
# ----------------------------------------
# Optim Trajctory:
# [[1500.      2000.       250.     ]
#  [1203.08683 1488.39004  262.77439]
#  [1022.609   1348.77159  275.47471]
#  [ 875.90232 1320.21395  291.98904]
#  [ 766.92865 1339.95382  311.84744]
#  [ 688.80147 1369.66642  332.01501]
#  [ 634.52369 1394.42025  349.9258 ]
#  [ 599.40348 1409.89971  363.77655]
#  [ 580.7426  1416.18063  372.46563]
#  [ 577.06651 1415.03538  375.50903]
#  [ 587.49136 1408.80458  372.96368]
#  [ 611.28738 1399.91562  365.3543 ]
#  [ 647.59897 1390.65855  353.58988]
#  [ 695.2795  1383.06706  338.85909]
#  [ 752.80756 1378.85214  322.50548]
#  [ 818.25873 1379.37514  305.89109]
#  [ 889.32474 1385.64737  290.25164]
#  [ 963.43133 1398.30765  276.53168]
#  [1038.09403 1417.50742  265.22059]
#  [1200.      1500.       250.     ]]
# ------------------------------------
# Optim Trajectory Legibility: 0.85511
# ------------------------------------
# Optim User Legibilities:
# User1 legibility: 0.90881
# User2 legibility: 0.75236
# User3 legibility: 0.90415
# ------------------------------------
#
#
# -------------------------------------------------
# |-----------------------------------------------|
# |                                               |
# |         Results For All Defined Users         |
# |                                               |
# |-----------------------------------------------|
# -------------------------------------------------
# ------------------------
# Legibility for each user
# User1 legibility: 0.90881
# User2 legibility: 0.75236
# User3 legibility: 0.90415
# -------------------------
# Average Legibility: 0.85511
# -------------------------
#
#
#
#
# --------------------------------
# | Storing Trajectories to file |
# --------------------------------
# ------------------------------------------
# -------- OPTIMIZATION PROGRAM ENDED ------
# ------------------------------------------
